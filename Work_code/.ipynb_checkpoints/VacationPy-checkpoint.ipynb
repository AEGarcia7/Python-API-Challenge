# %% [markdown]
# # VacationPy
# ----
#
# #### Note
# * Keep an eye on your API usage. Use https://developers.google.com/maps/reporting/gmp-reporting as reference for how to monitor your usage and billing.
#
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import gmaps
import os

# Import API key
from api_keys import g_key

# %% [markdown]
# ### Store Part I results into DataFrame
# * Load the csv exported in Part I to a DataFrame

# %%
weather_data = pd.read_csv("./cities.csv")
weather_data.dropna()
weather_data.head()
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         Kenai  60.5544 -151.2583     55.02        85         100
# 1       Ushuaia -54.8000  -68.3000     38.86        60          75
# 2         Seoul  37.5683  126.9778     78.19       100         100
# 3  Kruisfontein -34.0033   24.7314     49.89        89          95
# 4    Townsville -19.2500  146.8000     72.48        43           0
#
#    Wind Speed Country        Date
# 0       17.27      US  1660015032
# 1       10.36      AR  1660015315
# 2        6.91      KR  1660015316
# 3        7.23      ZA  1660015316
# 4       14.97      AU  1660015100

# %% [markdown]
# ### Humidity Heatmap
# * Configure gmaps.
# * Use the Lat and Lng as locations and Humidity as the weight.
# * Add Heatmap layer to map.

# %%
gmaps.configure(api_key=g_key)

# Locations is Lat, Long
locations = weather_data[["Lat", "Lng"]]

humidity = weather_data["Humidity"]

# %%
# Bring in location data pairs, humidity data, define map and layer, and add layer to map
fig = gmaps.figure(center = [0,0] ,zoom_level = 2)

#Create and add heat layer 
heat_layer = gmaps.heatmap_layer(locations, weights=humidity,
                               dissipating=False, max_intensity=100,
                               point_radius = 3)
fig.add_layer(heat_layer)

fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %% [markdown]
# ### Create new DataFrame fitting weather criteria
# * Narrow down the cities to fit weather conditions.
# * Drop any rows will null values.

# %%
# Max temperature lower than 80 degrees but higher than 70.

# Wind speed less than 10 mph.

# Zero cloudiness

# Drop N/A

fixed_data_df = weather_data.loc[(weather_data["Max Temp"] >= 70) & (weather_data["Max Temp"] <= 80) & (weather_data["Wind Speed"] <= 10) & (weather_data["Cloudiness"] == 0)].dropna()

fixed_data_df
# Out:
#                           City      Lat       Lng  Max Temp  Humidity  \
# 19                  Vila Velha -20.3297  -40.2925     73.35        86
# 40                    Mincivan  39.0294   46.7185     74.62        68
# 48               Káto Mazaráki  38.0667   21.6500     78.40        52
# 77                      Mizdah  31.4451   12.9801     70.52        69
# 298               Ponta do Sol  32.6667  -17.1000     71.71        80
# 300                 Isla Vista  34.4133 -119.8610     79.02        64
# 305                   Harrison  30.4091  -89.0436     77.07        91
# 309                       Rome  43.2128  -75.4557     77.67        94
# 325                   Lokosovo  61.1333   74.8167     73.49        58
# 358                       İdil  37.3411   41.8895     79.09        33
# 359                    Kongolo  -5.3833   27.0000     71.94        38
# 390                    Sukhumi  43.0033   41.0153     71.60        51
# 414                    Tigzirt  36.8886    4.1198     79.43        51
# 420                      Ilebo  -4.3167   20.5833     70.05        39
# 445                       Jalu  29.0331   21.5482     78.87        65
# 461  Arrondissement d'Arcachon  44.5875   -1.0519     71.92        45
# 463                    Borovoy  55.4333   86.0833     70.88        60
# 464                Sevierville  35.8681  -83.5618     78.44        87
# 475              Ribeira Brava  32.6500  -17.0667     71.71        81
# 524                     Sonqor  34.7837   47.6004     74.80        26
#
#      Cloudiness  Wind Speed Country        Date
# 19            0        3.44      BR  1660015320
# 40            0        0.47      AZ  1660015326
# 48            0        4.97      GR  1660015329
# 77            0        2.53      LY  1660015338
# 298           0        3.60      PT  1660015406
# 300           0        5.75      US  1660015407
# 305           0        3.44      US  1660015409
# 309           0        0.00      US  1660015410
# 325           0        3.62      RU  1660015415
# 358           0        2.17      TR  1660015430
# 359           0        1.45      CD  1660015430
# 390           0        4.41      GE  1660015440
# 414           0        7.45      DZ  1660015449
# 420           0        0.60      CD  1660015452
# 445           0        8.79      LY  1660015465
# 461           0        6.91      FR  1660015470
# 463           0        8.95      RU  1660015471
# 464           0        0.00      US  1660015471
# 475           0        3.29      PT  1660015474
# 524           0        3.98      IR  1660015487

# %% [markdown]
# ### Hotel Map
# * Create a dataframe named `hotel_df` that is the df created above only with the pertinent data.  See the prepared code below (`info_box_template`) to determine what data you will need for your final map.
# * Add a "Hotel Name" column to the DataFrame.
# * Set parameters to search for hotels (aka "lodging") within 5000 meters.
# * Utilize the Google Places API to find the first hotel search result.
# * Store the first Hotel result into the DataFrame.
# * Plot markers on top of the heatmap.

# %%
# Create dataframe and empty column
hotel_df = pd.DataFrame(weather_data, columns=["City", "Country", "Lat", "Lng"])

hotel_df["Hotel Name"] = ""

hotel_df
# Out:
#               City Country      Lat       Lng Hotel Name
# 0            Kenai      US  60.5544 -151.2583
# 1          Ushuaia      AR -54.8000  -68.3000
# 2            Seoul      KR  37.5683  126.9778
# 3     Kruisfontein      ZA -34.0033   24.7314
# 4       Townsville      AU -19.2500  146.8000
# ..             ...     ...      ...       ...        ...
# 557        Estelle      US  29.8458  -90.1067
# 558         Sabang      ID   5.8933   95.3214
# 559       Havelock      US  34.8791  -76.9013
# 560      Geraldton      AU -28.7667  114.6000
# 561  Leshukonskoye      RU  64.8989   45.7622
#
# [562 rows x 5 columns]

# %%
# Prepping the api search
base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"

params = {"type" : "hotel",
          "keyword" : "hotel",
          "radius" : 5000,
          "key" : g_key}

# %%
# Loop through dataframe and add nearby hotel result

for index, row in hotel_df.iterrows():
    # Retrieve necessary info from the datafram
    lat = row["Lat"]
    lng = row["Lng"]
    city_name = row["City"]
    hotel_name = ["name"]
    
    # add keyword to params dict
    params["location"] = f"{lat},{lng}"

    # assemble url and make API request
    print(f"Retrieving Results for Index {index}: {city_name}.")
    response = requests.get(base_url, params=params).json()
    
    # extract results
    results = response['results']
    
    # save the hotel name to dataframe
    try:
        print(f"The closest hotel to {city_name} is {results[0]['name']}.")
        hotel_df.loc[index, "Hotel Name"] = results[0]['name']

    # If somwthing goes wrong, skip it to not crash the call
    except (KeyError, IndexError):
        print("---Missing info... skipping---.")
        
    print("------------")
    

# Print end of search once searching is completed
print("------Search Complete-------")
# Out:
# Retrieving Results for Index 0: Kenai.
# The closest hotel to Kenai is Aspen Extended Stay Suites.
# ------------
# Retrieving Results for Index 1: Ushuaia.
# The closest hotel to Ushuaia is Hotel Lennox.
# ------------
# Retrieving Results for Index 2: Seoul.
# The closest hotel to Seoul is Four Seasons Hotel Seoul.
# ------------
# Retrieving Results for Index 3: Kruisfontein.
# The closest hotel to Kruisfontein is Humansdorp Boutique Hotel.
# ------------
# Retrieving Results for Index 4: Townsville.
# The closest hotel to Townsville is Dalrymple Hotel.
# ------------
# Retrieving Results for Index 5: Muhos.
# The closest hotel to Muhos is Montta - active camping / campsite Montan.
# ------------
# Retrieving Results for Index 6: Nara.
# The closest hotel to Nara is Okuyama Nara Kasuga Tsukihitei.
# ------------
# Retrieving Results for Index 7: Harbour Breton.
# The closest hotel to Harbour Breton is Southern Port Hotel.
# ------------
# Retrieving Results for Index 8: Dikson.
# ---Missing info... skipping---.
# ------------
# Retrieving Results for Index 9: New Norfolk.
# ---Missing info... skipping---.
# ------------
# Retrieving Results for Index 10: Jamestown.
# The closest hotel to Jamestown is Chautauqua Harbor Hotel.
# ------------
# Retrieving Results for Index 11: Bengkulu.
# The closest hotel to Bengkulu is Mercure Bengkulu.
# ------------
# Retrieving Results for Index 12: Puerto Ayora.
# The closest hotel to Puerto Ayora is Finch Bay Galapagos Hotel.
# ------------
# Retrieving Results for Index 13: Khatanga.
# ---Missing info... skipping---.
# ------------
# Retrieving Results for Index 14: Yellowknife.
# The closest hotel to Yellowknife is The Explorer Hotel.
# ------------
# Retrieving Results for Index 15: Punta Arenas.
# The closest hotel to Punta Arenas is Hotel Almasur Punta Arenas.
# ------------
# Retrieving Results for Index 16: Tasiilaq.
# The closest hotel to Tasiilaq is Hotel Angmagssalik.
# ------------
# Retrieving Results for Index 17: Luwuk.
# The closest hotel to Luwuk is Swiss-Belinn Hotel Luwuk.
# ------------
# Retrieving Results for Index 18: Vila.
# The closest hotel to Vila is Hotel Castrum Villae.
# ------------
# Retrieving Results for Index 19: Vila Velha.
# The closest hotel to Vila Velha is Quality Suites Vila Velha.
# ------------
# Retrieving Results for Index 20: Kapaa.
# The closest hotel to Kapaa is The ISO.
# ------------
# Retrieving Results for Index 21: Hermanus.
# The closest hotel to Hermanus is Harbour House Hotel.
# ------------
# Retrieving Results for Index 22: Saint George.
# The closest hotel to Saint George is The Advenire, Autograph Collection.
# ------------
# Retrieving Results for Index 23: Lompoc.
# The closest hotel to Lompoc is O'Cairns Inn & Suites.
# ------------
# Retrieving Results for Index 24: Otane.
# The closest hotel to Otane is Ludlow Farmstay.
# ------------
# Retrieving Results for Index 25: Tuktoyaktuk.
# The closest hotel to Tuktoyaktuk is End of The Road Ltd..
# ------------
# Retrieving Results for Index 26: Tual.
# The closest hotel to Tual is Grand Vilia Hotel.
# ------------
# Retrieving Results for Index 27: Vaini.
# The closest hotel to Vaini is Paradise First Hotel.
# ------------
# Retrieving Results for Index 28: Thompson.
# The closest hotel to Thompson is Best Western Thompson Hotel & Suites.
# ------------
# Retrieving Results for Index 29: Carnarvon.
# The closest hotel to Carnarvon is Hospitality Carnarvon.
# ------------
# Retrieving Results for Index 30: Busselton.
# The closest hotel to Busselton is Busselton Motel.
# ------------
# Retrieving Results for Index 31: Bluff.
# The closest hotel to Bluff is Land's End Boutique Hotel.
# ------------
# Retrieving Results for Index 32: Fort Nelson.
# The closest hotel to Fort Nelson is Lakeview Inns & Suites - Fort Nelson.
# ------------
# Retrieving Results for Index 33: Rikitea.
# The closest hotel to Rikitea is Pension Bianca & Benoit.
# ------------
# Retrieving Results for Index 34: Longyearbyen.
# The closest hotel to Longyearbyen is Radisson Blu Polar Hotel, Spitsbergen.
# ------------
# Retrieving Results for Index 35: Mataura.
# The closest hotel to Mataura is Ellie's Villa.
# ------------
# Retrieving Results for Index 36: East London.
# The closest hotel to East London is Garden Court East London.
# ------------
# Retrieving Results for Index 37: Paamiut.
# ---Missing info... skipping---.
# ------------
# Retrieving Results for Index 38: Okhotsk.
# ---Missing info... skipping---.
# ------------
# Retrieving Results for Index 39: Cape Town.
# The closest hotel to Cape Town is The Bay Hotel.
# ------------
# Retrieving Results for Index 40: Mincivan.
# ---Missing info... skipping---.
# ------------
# Retrieving Results for Index 41: Khani.
# The closest hotel to Khani is hotel alismereti.
# ------------
# Retrieving Results for Index 42: Quatre Cocos.
# The closest hotel to Quatre Cocos is Shangri-La Le Touessrok, Mauritius.
# ------------
# Retrieving Results for Index 43: Qaanaaq.
# ---Missing info... skipping---.
# ------------
# Retrieving Results for Index 44: Axams.
# The closest hotel to Axams is Hotel.
# ------------
# Retrieving Results for Index 45: Barentu.
# ---Missing info... skipping---.
# ------------
# Retrieving Results for Index 46: Lindi.
# The closest hotel to Lindi is Sea View Beach Resort.
# ------------
# Retrieving Results for Index 47: Narsaq.
# The closest hotel to Narsaq is Igdlo Guesthouse.
# ------------
# Retrieving Results for Index 48: Káto Mazaráki.
# ---Missing info... skipping---.
# ------------
# Retrieving Results for Index 49: Mahébourg.
# The closest hotel to Mahébourg is Anantara Iko Mauritius Resort & Villas.
# ------------
# Retrieving Results for Index 50: Uglovskoye.
# ---Missing info... skipping---.
# ------------
# Retrieving Results for Index 51: Bonfim.
# ---Missing info... skipping---.
# ------------
# Retrieving Results for Index 52: Bloomington.
# The closest hotel to Bloomington is Radisson Blu Mall of America.
# ------------
# Retrieving Results for Index 53: Canutama.
# ---Missing info... skipping---.
# ------------
# Retrieving Results for Index 54: Alyangula.
# ---Missing info... skipping---.
# ------------
# Retrieving Results for Index 55: Lebu.
# The closest hotel to Lebu is Hotel Plaza Lebu.
# ------------
# Retrieving Results for Index 56: Dwārka.
# The closest hotel to Dwārka is The Dwarika Hotel.
# ------------
# Retrieving Results for Index 57: Butaritari.
# ---Missing info... skipping---.
# ------------
# Retrieving Results for Index 58: Dali.
# The closest hotel to Dali is LUX* Tea Horse Road Dali.
# ------------
# Retrieving Results for Index 59: Bethel.
# The closest hotel to Bethel is Hampton Inn Danbury.
# ------------
# Retrieving Results for Index 60: Nortelândia.
# The closest hotel to Nortelândia is Hotel Karysmã.
# ------------
# Retrieving Results for Index 61: Barrow.
# The closest hotel to Barrow is Top of the World Hotel.
# ------------
# Retrieving Results for Index 62: Hobart.
# The closest hotel to Hobart is Salamanca Wharf Hotel.
# ------------
# Retrieving Results for Index 63: Nikolskoye.
# The closest hotel to Nikolskoye is Tourist House - Sablino.
# ------------
# Retrieving Results for Index 64: Avarua.
# The closest hotel to Avarua is The Islander Hotel.
# ------------
# Retrieving Results for Index 65: Provideniya.
# ---Missing info... skipping---.
# ------------
# Retrieving Results for Index 66: Dumai.
# The closest hotel to Dumai is Sonaview Hotel Dumai.
# ------------
# Retrieving Results for Index 67: Castro.
# The closest hotel to Castro is Central Palace Hotel.
# ------------
# Retrieving Results for Index 68: Santiago del Estero.
# The closest hotel to Santiago del Estero is Hilton Garden Inn Santiago del Estero.
# ------------
# Retrieving Results for Index 69: Moen.
# ---Missing info... skipping---.
# ------------
# Retrieving Results for Index 70: Ma-ao.
# The closest hotel to Ma-ao is Gianna's Mountain Resort.
# ------------
# Retrieving Results for Index 71: Hithadhoo.
# The closest hotel to Hithadhoo is Clovebeach.
# ------------
# Retrieving Results for Index 72: Pedernales.
# The closest hotel to Pedernales is Hotel Villas Del Mar.
# ------------
# Retrieving Results for Index 73: Chapais.
# The closest hotel to Chapais is Hôtel Opémiska.
# ------------
# Retrieving Results for Index 74: Shintomi.
# The closest hotel to Shintomi is Hotel AZ Miyazaki Shintomi.
# ------------
# Retrieving Results for Index 75: Torbay.
# The closest hotel to Torbay is See The Sea.
# ------------
# Retrieving Results for Index 76: Rio Branco.
# The closest hotel to Rio Branco is ibis Rio Branco.
# ------------
# Retrieving Results for Index 77: Mizdah.
# ---Missing info... skipping---.
# ------------
# Retrieving Results for Index 78: San Cristobal.
# The closest hotel to San Cristobal is Lidotel Hotel Boutique San Cristobal.
# ------------
# Retrieving Results for Index 79: Wanning.
# The closest hotel to Wanning is Mando Hotel.
# ------------
# Retrieving Results for Index 80: Biak.
# ---Missing info... skipping---.
# ------------
# Retrieving Results for Index 81: Ahipara.
# The closest hotel to Ahipara is The Huts.
# ------------
# Retrieving Results for Index 82: Monrovia.
# The closest hotel to Monrovia is The Royal Grand Hotel.
# ------------
# Retrieving Results for Index 83: Hanstholm.
# The closest hotel to Hanstholm is Hotel Hanstholm.
# ------------
# Retrieving Results for Index 84: Lavrentiya.
# ---Missing info... skipping---.
# ------------
# Retrieving Results for Index 85: Prince Rupert.
# The closest hotel to Prince Rupert is Crest Hotel.
# ------------
# Retrieving Results for Index 86: Westport.
# The closest hotel to Westport is Norwalk Inn.
# ------------
# Retrieving Results for Index 87: High Level.
# The closest hotel to High Level is Best Western Plus Mirage Hotel & Resort.
# ------------
# Retrieving Results for Index 88: Ribeira Grande.
# The closest hotel to Ribeira Grande is Lofts Pastel Blue. Pub.
# ------------
# Retrieving Results for Index 89: Klyuchi.
# ---Missing info... skipping---.
# ------------
# Retrieving Results for Index 90: Santa Flavia.
# The closest hotel to Santa Flavia is Zagarella Domina Sicily.
# ------------
# Retrieving Results for Index 91: Wau.
# The closest hotel to Wau is Royal castle Hotel wau, South Sudan.
# ------------
# Retrieving Results for Index 92: Bredasdorp.
# The closest hotel to Bredasdorp is Victoria Hotel - Bredasdorp.
# ------------
# Retrieving Results for Index 93: Arrondissement du Havre.
# The closest hotel to Arrondissement du Havre is Manoir de l'oiselière.
# ------------
# Retrieving Results for Index 94: George Town.
# The closest hotel to George Town is Eastern & Oriental Hotel, Penang.
# ------------
# Retrieving Results for Index 95: Bambous Virieux.
# The closest hotel to Bambous Virieux is La Case du Pêcheur.
# ------------
# Retrieving Results for Index 96: Sinnamary.
# The closest hotel to Sinnamary is Hotel Du Fleuve.
# ------------
# Retrieving Results for Index 97: Vanavara.
# ---Missing info... skipping---.
# ------------
# Retrieving Results for Index 98: Pozo Colorado.
# ---Missing info... skipping---.
# ------------
# Retrieving Results for Index 99: Cayenne.
# The closest hotel to Cayenne is Grand Hotel Montabo.
# ------------
# Retrieving Results for Index 100: Norman Wells.
# The closest hotel to Norman Wells is Heritage Hotel.
# ------------
# Retrieving Results for Index 101: Ostrovnoy.
# ---Missing info... skipping---.
# ------------
# Retrieving Results for Index 102: Atuona.
# The closest hotel to Atuona is Hôtel Hiva Oa Hanakee Lodge.
# ------------
# Retrieving Results for Index 103: Gizo Government Station.
# The closest hotel to Gizo Government Station is Imagination Island.
# ------------
# Retrieving Results for Index 104: Aktobe.
# The closest hotel to Aktobe is ibis Aktobe.
# ------------
# Retrieving Results for Index 105: Tadine.
# The closest hotel to Tadine is YEJELE BEACH MOTEL.
# ------------
# Retrieving Results for Index 106: Hambantota.
# The closest hotel to Hambantota is The Peacock Beach Hotel Hambantota.
# ------------
# Retrieving Results for Index 107: Saint-Augustin.
# ---Missing info... skipping---.
# ------------
# Retrieving Results for Index 108: Faanui.
# The closest hotel to Faanui is InterContinental Bora Bora Resort Thalasso Spa.
# ------------
# Retrieving Results for Index 109: Padang.
# The closest hotel to Padang is Hotel Princessa.
# ------------
# Retrieving Results for Index 110: Acheng.
# The closest hotel to Acheng is Yijin Hotel.
# ------------
# Retrieving Results for Index 111: Griffith.
# The closest hotel to Griffith is Holiday Inn Express & Suites Hammond, an IHG Hotel.
# ------------
# Retrieving Results for Index 112: Wagar.
# ---Missing info... skipping---.
# ------------
# Retrieving Results for Index 113: Pirapora do Bom Jesus.
# The closest hotel to Pirapora do Bom Jesus is Hotel Casarão.
# ------------
# Retrieving Results for Index 114: Guanaja.
# ---Missing info... skipping---.
# ------------
# Retrieving Results for Index 115: Yeppoon.
# The closest hotel to Yeppoon is Bayview Tower.
# ------------
# Retrieving Results for Index 116: Mar del Plata.
# The closest hotel to Mar del Plata is NH Gran Hotel Provincial.
# ------------
# Retrieving Results for Index 117: Katsuura.
# The closest hotel to Katsuura is Katsuura Hotel Mikazuki.
# ------------
# Retrieving Results for Index 118: Portland.
# The closest hotel to Portland is River's Edge Hotel.
# ------------
# Retrieving Results for Index 119: Kiruna.
# The closest hotel to Kiruna is Spis hotel and hostel.
# ------------
# Retrieving Results for Index 120: Coquimbo.
# The closest hotel to Coquimbo is Hostel Del Puerto.
# ------------
# Retrieving Results for Index 121: Bilibino.
# The closest hotel to Bilibino is Profilaktoriy Baes.
# ------------
# Retrieving Results for Index 122: Shizunai-furukawachō.
# The closest hotel to Shizunai-furukawachō is Shizunai Eclipse Hotel.
# ------------
# Retrieving Results for Index 123: Klamath Falls.
# The closest hotel to Klamath Falls is Holiday Inn Express & Suites Klamath Falls Central, an IHG Hotel.
# ------------
# Retrieving Results for Index 124: Caravelas.
# The closest hotel to Caravelas is Pousada Liberdade.
# ------------
# Retrieving Results for Index 125: Bariloche.
# The closest hotel to Bariloche is Bahía Paraíso Luxury Suites.
# ------------
# Retrieving Results for Index 126: Umba.
# The closest hotel to Umba is Cedar Grass Beloye More.
# ------------
# Retrieving Results for Index 127: Mugur-Aksy.
# ---Missing info... skipping---.
# ------------
# Retrieving Results for Index 128: Kirakira.
# ---Missing info... skipping---.
# ------------
# Retrieving Results for Index 129: Golden.
# The closest hotel to Golden is Holiday Inn Express & Suites Golden - Denver Area, an IHG Hotel.
# ------------
# Retrieving Results for Index 130: Praia da Vitória.
# The closest hotel to Praia da Vitória is Atlântida Mar Hotel.
# ------------
# Retrieving Results for Index 131: Nogliki.
# The closest hotel to Nogliki is Hotel "Nogliki".
# ------------
# Retrieving Results for Index 132: Nyurba.
# ---Missing info... skipping---.
# ------------
# Retrieving Results for Index 133: Asău.
# The closest hotel to Asău is Cabana Duca.
# ------------
# Retrieving Results for Index 134: Port Alfred.
# The closest hotel to Port Alfred is The Halyards Hotel.
# ------------
# Retrieving Results for Index 135: Nanortalik.
# The closest hotel to Nanortalik is Hotel Kap Farvel.
# ------------
# Retrieving Results for Index 136: Isangel.
# The closest hotel to Isangel is Tanna Ikamir Guest House.
# ------------
# Retrieving Results for Index 137: Alfred.
# The closest hotel to Alfred is Saxon Inn.
# ------------
# Retrieving Results for Index 138: Te Anau.
# The closest hotel to Te Anau is Distinction Luxmore Hotel Te Anau.
# ------------
# Retrieving Results for Index 139: Nago.
# The closest hotel to Nago is HOTEL HOUKLEA（ホークレア）.
# ------------
# Retrieving Results for Index 140: Kaitangata.
# The closest hotel to Kaitangata is Kaitangata Motor Camp.
# ------------
# Retrieving Results for Index 141: São Filipe.
# The closest hotel to São Filipe is Hotel Savana.
# ------------
# Retrieving Results for Index 142: Touros.
# The closest hotel to Touros is Hotel Vila Gale Touros.
# ------------
# Retrieving Results for Index 143: Sitka.
# The closest hotel to Sitka is Westmark Sitka.
# ------------
# Retrieving Results for Index 144: Roald.
# The closest hotel to Roald is Smartrom.
# ------------
# Retrieving Results for Index 145: Flinders.
# The closest hotel to Flinders is Oaks Hotel Motel.
# ------------
# Retrieving Results for Index 146: Farafangana.
# ---Missing info... skipping---.
# ------------
# Retrieving Results for Index 147: Kallaste.
# The closest hotel to Kallaste is Nina Kordon Guesthouse.
# ------------
# Retrieving Results for Index 148: Korla.
# The closest hotel to Korla is The Garden Hotel Korla.
# ------------
# Retrieving Results for Index 149: Boulsa.
# ---Missing info... skipping---.
# ------------
# Retrieving Results for Index 150: Vao.
# The closest hotel to Vao is OURE TERA beach resort.
# ------------
# Retrieving Results for Index 151: Tugulym.
# ---Missing info... skipping---.
# ------------
# Retrieving Results for Index 152: Östersund.
# The closest hotel to Östersund is Clarion Hotel Grand Östersund.
# ------------
# Retrieving Results for Index 153: Ancud.
# The closest hotel to Ancud is Panamericana Hotel Ancud.
# ------------
# Retrieving Results for Index 154: Fukuechō.
# The closest hotel to Fukuechō is SERENDIP HOTEL GOTO.
# ------------
# Retrieving Results for Index 155: Chui.
# The closest hotel to Chui is Hotel Internacional.
# ------------
# Retrieving Results for Index 156: Hilo.
# The closest hotel to Hilo is SCP Hilo Hotel.
# ------------
# Retrieving Results for Index 157: Saint-Philippe.
# The closest hotel to Saint-Philippe is Hôtel Les Embruns Du Baril.
# ------------
# Retrieving Results for Index 158: San Antonio.
# The closest hotel to San Antonio is Holiday Inn Express Building 592.
# ------------
# Retrieving Results for Index 159: Raja.
# ---Missing info... skipping---.
# ------------
# Retrieving Results for Index 160: Birao.
# ---Missing info... skipping---.
# ------------
# Retrieving Results for Index 161: Dera Bugti.
# ---Missing info... skipping---.
# ------------
# Retrieving Results for Index 162: Albany.
# ---Missing info... skipping---.
# ------------
# Retrieving Results for Index 163: Charters Towers.
# The closest hotel to Charters Towers is Park Hotel Motel.
# ------------
# Retrieving Results for Index 164: Qaqortoq.
# ---Missing info... skipping---.
# ------------
# Retrieving Results for Index 165: Alice Springs.
# The closest hotel to Alice Springs is Crowne Plaza Alice Springs Lasseters, an IHG Hotel.
# ------------
# Retrieving Results for Index 166: Genhe.
# The closest hotel to Genhe is Forest Snow Hotel.
# ------------
# Retrieving Results for Index 167: Cidreira.
# The closest hotel to Cidreira is Hotel Castelo.
# ------------
# Retrieving Results for Index 168: Baoding.
# The closest hotel to Baoding is Xingguang International Business Hotel.
# ------------
# Retrieving Results for Index 169: Mgandu.
# ---Missing info... skipping---.
# ------------
# Retrieving Results for Index 170: Port Macquarie.
# The closest hotel to Port Macquarie is ibis Styles Port Macquarie.
# ------------
# Retrieving Results for Index 171: Moree.
# The closest hotel to Moree is Albert Motel.
# ------------
# Retrieving Results for Index 172: Skjervøy.
# The closest hotel to Skjervøy is Hotel Maritim Skjervøy AS.
# ------------
# Retrieving Results for Index 173: San Patricio.
# The closest hotel to San Patricio is Motel 6 Sinton, TX.
# ------------
# Retrieving Results for Index 174: Krasnosel'kup.
# ---Missing info... skipping---.
# ------------
# Retrieving Results for Index 175: Flin Flon.
# The closest hotel to Flin Flon is Victoria Inn Flin Flon.
# ------------
# Retrieving Results for Index 176: Buraidah.
# The closest hotel to Buraidah is Mövenpick Qassim.
# ------------
# Retrieving Results for Index 177: Henties Bay.
# The closest hotel to Henties Bay is Desert Rose.
# ------------
# Retrieving Results for Index 178: Inta.
# The closest hotel to Inta is Отель Инта.
# ------------
# Retrieving Results for Index 179: Ust-Nera.
# ---Missing info... skipping---.
# ------------
# Retrieving Results for Index 180: Pevek.
# ---Missing info... skipping---.
# ------------
# Retrieving Results for Index 181: Enshi.
# The closest hotel to Enshi is Moevenpick Enshi.
# ------------
# Retrieving Results for Index 182: Ilulissat.
# The closest hotel to Ilulissat is Hotel Arctic.
# ------------
# Retrieving Results for Index 183: Paptalaya.
# ---Missing info... skipping---.
# ------------
# Retrieving Results for Index 184: Dashitou.
# The closest hotel to Dashitou is Floral Hotel· jisen sojourn health park.
# ------------
# Retrieving Results for Index 185: Mbini.
# ---Missing info... skipping---.
# ------------
# Retrieving Results for Index 186: Esperance.
# The closest hotel to Esperance is The Jetty Resort.
# ------------
# Retrieving Results for Index 187: Vrangel'.
# The closest hotel to Vrangel' is Gostinichnyy Kompleks Vostok.
# ------------
# Retrieving Results for Index 188: Labuhan.
# ---Missing info... skipping---.
# ------------
# Retrieving Results for Index 189: Carauari.
# The closest hotel to Carauari is Tatiana's Hotel.
# ------------
# Retrieving Results for Index 190: Boa Vista.
# The closest hotel to Boa Vista is ibis Styles Boa Vista.
# ------------
# Retrieving Results for Index 191: Buala.
# ---Missing info... skipping---.
# ------------
# Retrieving Results for Index 192: Brae.
# The closest hotel to Brae is Busta House Hotel.
# ------------
# Retrieving Results for Index 193: Codrington.
# The closest hotel to Codrington is Codrington Gardens Bed And Breakfast.
# ------------
# Retrieving Results for Index 194: Bathsheba.
# The closest hotel to Bathsheba is Santosha Barbados.
# ------------
# Retrieving Results for Index 195: Hong Kong.
# The closest hotel to Hong Kong is The T Hotel.
# ------------
# Retrieving Results for Index 196: Mahibadhoo.
# The closest hotel to Mahibadhoo is Kuri Beach View Inn.
# ------------
# Retrieving Results for Index 197: Puerto Baquerizo Moreno.
# The closest hotel to Puerto Baquerizo Moreno is Sea Side Inn Hotel.
# ------------
# Retrieving Results for Index 198: Fryanovo.
# The closest hotel to Fryanovo is Country hotel MB-Resort.
# ------------
# Retrieving Results for Index 199: Grand Gaube.
# The closest hotel to Grand Gaube is Lagoon Attitude Hotel.
# ------------
# Retrieving Results for Index 200: Kuusamo.
# The closest hotel to Kuusamo is Holiday Club Kuusamo.
# ------------
# Retrieving Results for Index 201: Bubaque.
# The closest hotel to Bubaque is Ponta Anchaca.
# ------------
# Retrieving Results for Index 202: Camacha.
# The closest hotel to Camacha is Pestana Porto Santo.
# ------------
# Retrieving Results for Index 203: Talnakh.
# The closest hotel to Talnakh is Talnakh Hotel.
# ------------
# Retrieving Results for Index 204: Coos Bay.
# The closest hotel to Coos Bay is Best Western Holiday Hotel.
# ------------
# Retrieving Results for Index 205: Visnes.
# The closest hotel to Visnes is Park Inn Haugesund Airport.
# ------------
# Retrieving Results for Index 206: Pandan.
# ---Missing info... skipping---.
# ------------
# Retrieving Results for Index 207: Husavik.
# The closest hotel to Husavik is Húsavík Cape Hotel.
# ------------
# Retrieving Results for Index 208: Samarai.
# The closest hotel to Samarai is Nuli Sapi.
# ------------
# Retrieving Results for Index 209: Severo-Kuril'sk.
# ---Missing info... skipping---.
# ------------
# Retrieving Results for Index 210: Urubichá.
# ---Missing info... skipping---.
# ------------
# Retrieving Results for Index 211: Margate.
# The closest hotel to Margate is Botany Bay Hotel.
# ------------
# Retrieving Results for Index 212: Fairbanks.
# The closest hotel to Fairbanks is Westmark Fairbanks Hotel & Conference Center.
# ------------
# Retrieving Results for Index 213: Klaksvík.
# The closest hotel to Klaksvík is Hotel Klaksvík.
# ------------
# Retrieving Results for Index 214: Port Hedland.
# The closest hotel to Port Hedland is Hospitality Port Hedland.
# ------------
# Retrieving Results for Index 215: Sioux Lookout.
# The closest hotel to Sioux Lookout is Sioux Lookout Inn & Suites.
# ------------
# Retrieving Results for Index 216: Port Elizabeth.
# The closest hotel to Port Elizabeth is Herms Restaurant and Boutique Hotel.
# ------------
# Retrieving Results for Index 217: Raudeberg.
# The closest hotel to Raudeberg is Ulvesund FYR.
# ------------
# Retrieving Results for Index 218: Dingle.
# The closest hotel to Dingle is Vaccinated Staff - OYO 236 Hotel Edmundo.
# ------------
# Retrieving Results for Index 219: Camaná.
# The closest hotel to Camaná is Fragata Camaná.
# ------------
# Retrieving Results for Index 220: Juneau.
# The closest hotel to Juneau is Four Points by Sheraton Juneau.
# ------------
# Retrieving Results for Index 221: Cabo San Lucas.
# The closest hotel to Cabo San Lucas is Medano Hotel and Suites.
# ------------
# Retrieving Results for Index 222: Quelimane.
# The closest hotel to Quelimane is Kansa Hotel.
# ------------
# Retrieving Results for Index 223: Plettenberg Bay.
# The closest hotel to Plettenberg Bay is Barrington's Small Hotel.
# ------------
# Retrieving Results for Index 224: Marzuq.
# ---Missing info... skipping---.
# ------------
# Retrieving Results for Index 225: Saint Paul Harbor.
# The closest hotel to Saint Paul Harbor is Kodiak Compass Suites.
# ------------
# Retrieving Results for Index 226: Crotone.
# The closest hotel to Crotone is Hotel San Giorgio.
# ------------
# Retrieving Results for Index 227: Oriximiná.
# The closest hotel to Oriximiná is Hotel Oriximiná.
# ------------
# Retrieving Results for Index 228: Staryy Nadym.
# ---Missing info... skipping---.
# ------------
# Retrieving Results for Index 229: Kroya.
# The closest hotel to Kroya is Arrya Guna Hotel Kemranjen.
# ------------
# Retrieving Results for Index 230: Ugento.
# The closest hotel to Ugento is Petra Bianca.
# ------------
# Retrieving Results for Index 231: Kandrian.
# ---Missing info... skipping---.
# ------------
# Retrieving Results for Index 232: Penzance.
# The closest hotel to Penzance is The Godolphin.
# ------------
# Retrieving Results for Index 233: Cockburn Town.
# The closest hotel to Cockburn Town is Osprey Beach Hotel.
# ------------
# Retrieving Results for Index 234: Togur.
# ---Missing info... skipping---.
# ------------
# Retrieving Results for Index 235: Pital.
# The closest hotel to Pital is Hotel juan felipe.
# ------------
# Retrieving Results for Index 236: Limanowa.
# The closest hotel to Limanowa is Hotel Limanova.
# ------------
# Retrieving Results for Index 237: Malinovskiy.
# ---Missing info... skipping---.
# ------------
# Retrieving Results for Index 238: Departamento de Maldonado.
# ---Missing info... skipping---.
# ------------
# Retrieving Results for Index 239: Bereda.
# The closest hotel to Bereda is Casa Grande de Anllo.
# ------------
# Retrieving Results for Index 240: Christchurch.
# The closest hotel to Christchurch is Golden Hotel.
# ------------
# Retrieving Results for Index 241: Dalvik.
# The closest hotel to Dalvik is Hótel Dalvík.
# ------------
# Retrieving Results for Index 242: Vilcún.
# The closest hotel to Vilcún is Hostal Amaranta Vilcún.
# ------------
# Retrieving Results for Index 243: Olafsvik.
# The closest hotel to Olafsvik is Hotel Olafsvik.
# ------------
# Retrieving Results for Index 244: Tocopilla.
# The closest hotel to Tocopilla is Hotel Galvarino.
# ------------
# Retrieving Results for Index 245: Rio Grande.
# The closest hotel to Rio Grande is Hotel Laghetto Viverone Rio Grande.
# ------------
# Retrieving Results for Index 246: Buin.
# The closest hotel to Buin is Hostal Condell.
# ------------
# Retrieving Results for Index 247: Tamiahua.
# The closest hotel to Tamiahua is Puerto Lobos Dive Camp.
# ------------
# Retrieving Results for Index 248: Bijāwar.
# ---Missing info... skipping---.
# ------------
# Retrieving Results for Index 249: Sarkand.
# ---Missing info... skipping---.
# ------------
# Retrieving Results for Index 250: Hailin.
# The closest hotel to Hailin is Grand Legend Hotel.
# ------------
# Retrieving Results for Index 251: Uchaly.
# The closest hotel to Uchaly is Иремель Гостиница.
# ------------
# Retrieving Results for Index 252: Mabamba.
# ---Missing info... skipping---.
# ------------
# Retrieving Results for Index 253: Kotido.
# The closest hotel to Kotido is La Maison Hotel Ltd.
# ------------
# Retrieving Results for Index 254: Upata.
# ---Missing info... skipping---.
# ------------
# Retrieving Results for Index 255: Upernavik.
# ---Missing info... skipping---.
# ------------
# Retrieving Results for Index 256: Neuquén.
# The closest hotel to Neuquén is Hotel Amucan.
# ------------
# Retrieving Results for Index 257: Arraial do Cabo.
# The closest hotel to Arraial do Cabo is Orlanova Hotel.
# ------------
# Retrieving Results for Index 258: Presidencia Roque Sáenz Peña.
# The closest hotel to Presidencia Roque Sáenz Peña is Hotel Gualok.
# ------------
# Retrieving Results for Index 259: Shimoda.
# The closest hotel to Shimoda is Shimoda Tokyu Hotel.
# ------------
# Retrieving Results for Index 260: Malanje.
# The closest hotel to Malanje is Palanca Hotel.
# ------------
# Retrieving Results for Index 261: Mehamn.
# The closest hotel to Mehamn is Mehamn Arctic Hotel AS.
# ------------
# Retrieving Results for Index 262: Hamilton.
# ---Missing info... skipping---.
# ------------
# Retrieving Results for Index 263: Borgarnes.
# The closest hotel to Borgarnes is Hótel Hamar.
# ------------
# Retrieving Results for Index 264: Carutapera.
# The closest hotel to Carutapera is Center Hotel.
# ------------
# Retrieving Results for Index 265: Yabēlo.
# ---Missing info... skipping---.
# ------------
# Retrieving Results for Index 266: Bahía Honda.
# ---Missing info... skipping---.
# ------------
# Retrieving Results for Index 267: Iztapa.
# The closest hotel to Iztapa is Iztapa Puerto Viejo.
# ------------
# Retrieving Results for Index 268: Lata.
# The closest hotel to Lata is Arouce Hostel.
# ------------
# Retrieving Results for Index 269: Coihueco.
# ---Missing info... skipping---.
# ------------
# Retrieving Results for Index 270: Antalaha.
# The closest hotel to Antalaha is Villa-Malaza.
# ------------
# Retrieving Results for Index 271: Salalah.
# The closest hotel to Salalah is Salalah Gardens Hotel.
# ------------
# Retrieving Results for Index 272: Rabo de Peixe.
# The closest hotel to Rabo de Peixe is Pedras do Mar Resort & SPA.
# ------------
# Retrieving Results for Index 273: Port Lincoln.
# The closest hotel to Port Lincoln is Port Lincoln Hotel.
# ------------
# Retrieving Results for Index 274: Camocim.
# The closest hotel to Camocim is Villa del Mar Praia Hotel.
# ------------
# Retrieving Results for Index 275: Şuraabad.
# ---Missing info... skipping---.
# ------------
# Retrieving Results for Index 276: Băiţa de sub Codru.
# ---Missing info... skipping---.
# ------------
# Retrieving Results for Index 277: Allonnes.
# The closest hotel to Allonnes is Hotel Le Circuit Le Mans.
# ------------
# Retrieving Results for Index 278: Laas.
# The closest hotel to Laas is Gasthof Hotel Sonne Silandro.
# ------------
# Retrieving Results for Index 279: Nyrob.
# ---Missing info... skipping---.
# ------------
# Retrieving Results for Index 280: Pitsunda.
# The closest hotel to Pitsunda is AMSHIN-PItsunda.
# ------------
# Retrieving Results for Index 281: Tiksi.
# ---Missing info... skipping---.
# ------------
# Retrieving Results for Index 282: Daru.
# ---Missing info... skipping---.
# ------------
# Retrieving Results for Index 283: Shumyachi.
# ---Missing info... skipping---.
# ------------
# Retrieving Results for Index 284: Kawalu.
# The closest hotel to Kawalu is Shanrilla Hotel.
# ------------
# Retrieving Results for Index 285: Aitape.
# ---Missing info... skipping---.
# ------------
# Retrieving Results for Index 286: Bertinoro.
# The closest hotel to Bertinoro is Grand Hotel Terme della Fratta.
# ------------
# Retrieving Results for Index 287: Cabatuan.
# The closest hotel to Cabatuan is Clada Travellers INN.
# ------------
# Retrieving Results for Index 288: Hasaki.
# The closest hotel to Hasaki is Inubosaki Hotel.
# ------------
# Retrieving Results for Index 289: Alofi.
# The closest hotel to Alofi is Taloa Heights.
# ------------
# Retrieving Results for Index 290: Two Hills.
# The closest hotel to Two Hills is Two Hills Inn & Liquor Store.
# ------------
# Retrieving Results for Index 291: Kavaratti.
# ---Missing info... skipping---.
# ------------
# Retrieving Results for Index 292: Pangnirtung.
# The closest hotel to Pangnirtung is Auyuittuq Lodge (Inns North).
# ------------
# Retrieving Results for Index 293: Khovd.
# The closest hotel to Khovd is Steppe hotel.
# ------------
# Retrieving Results for Index 294: San Andrés.
# The closest hotel to San Andrés is Hotel Molino de Viento.
# ------------
# Retrieving Results for Index 295: Dimitrovgrad.
# The closest hotel to Dimitrovgrad is Park Hotel D-grad.
# ------------
# Retrieving Results for Index 296: Skibbereen.
# The closest hotel to Skibbereen is The West Cork Hotel.
# ------------
# Retrieving Results for Index 297: Bud.
# ---Missing info... skipping---.
# ------------
# Retrieving Results for Index 298: Ponta do Sol.
# The closest hotel to Ponta do Sol is Enotel Sunset Bay.
# ------------
# Retrieving Results for Index 299: Ørje.
# The closest hotel to Ørje is Solstrand Bruk.
# ------------
# Retrieving Results for Index 300: Isla Vista.
# The closest hotel to Isla Vista is Hilton Garden Inn Santa Barbara/Goleta.
# ------------
# Retrieving Results for Index 301: Forécariah.
# ---Missing info... skipping---.
# ------------
# Retrieving Results for Index 302: Nemuro.
# The closest hotel to Nemuro is Hotel Nemuro Kaiyoutei.
# ------------
# Retrieving Results for Index 303: Aripuanã.
# ---Missing info... skipping---.
# ------------
# Retrieving Results for Index 304: Inírida.
# The closest hotel to Inírida is Hotel tucunaré.
# ------------
# Retrieving Results for Index 305: Harrison.
# The closest hotel to Harrison is Courtyard by Marriott Gulfport Beachfront.
# ------------
# Retrieving Results for Index 306: Los Llanos de Aridane.
# ---Missing info... skipping---.
# ------------
# Retrieving Results for Index 307: Teeli.
# ---Missing info... skipping---.
# ------------
# Retrieving Results for Index 308: Solnechnyy.
# The closest hotel to Solnechnyy is Hotel complex Pastoral.
# ------------
# Retrieving Results for Index 309: Rome.
# The closest hotel to Rome is Wingate By Wyndham Rome.
# ------------
# Retrieving Results for Index 310: Springbok.
# The closest hotel to Springbok is Springbok Inn by Country Hotels.
# ------------
# Retrieving Results for Index 311: Qasigiannguit.
# ---Missing info... skipping---.
# ------------
# Retrieving Results for Index 312: Seredka.
# ---Missing info... skipping---.
# ------------
# Retrieving Results for Index 313: Ballarat.
# The closest hotel to Ballarat is Mercure Ballarat - Hotel & Convention Centre.
# ------------
# Retrieving Results for Index 314: Kavieng.
# The closest hotel to Kavieng is Nusa Island Retreat.
# ------------
# Retrieving Results for Index 315: Port-Gentil.
# The closest hotel to Port-Gentil is Hôtel L'Hirondelle.
# ------------
# Retrieving Results for Index 316: Hirara.
# The closest hotel to Hirara is HOTEL LOCUS.
# ------------
# Retrieving Results for Index 317: Gold Coast.
# The closest hotel to Gold Coast is Hilton Surfers Paradise Hotel & Residences.
# ------------
# Retrieving Results for Index 318: Acaraú.
# The closest hotel to Acaraú is Hotel Riviera.
# ------------
# Retrieving Results for Index 319: Necochea.
# The closest hotel to Necochea is Hotel Firenze.
# ------------
# Retrieving Results for Index 320: Fortuna.
# The closest hotel to Fortuna is The Redwood Riverwalk.
# ------------
# Retrieving Results for Index 321: Srednekolymsk.
# ---Missing info... skipping---.
# ------------
# Retrieving Results for Index 322: Esim.
# The closest hotel to Esim is Ankobra Beach Resort.
# ------------
# Retrieving Results for Index 323: Tura.
# The closest hotel to Tura is Hotel Polo Orchid.
# ------------
# Retrieving Results for Index 324: Tokur.
# ---Missing info... skipping---.
# ------------
# Retrieving Results for Index 325: Lokosovo.
# ---Missing info... skipping---.
# ------------
# Retrieving Results for Index 326: Artigas.
# The closest hotel to Artigas is CASA VIOLETA HOTEL.
# ------------
# Retrieving Results for Index 327: Santa Isabel Rio Negro.
# ---Missing info... skipping---.
# ------------
# Retrieving Results for Index 328: Hauge i Dalane.
# The closest hotel to Hauge i Dalane is Sogndalstrand Kulturhotell.
# ------------
# Retrieving Results for Index 329: Chancay.
# The closest hotel to Chancay is El Mirador de Chancay.
# ------------
# Retrieving Results for Index 330: Forsytheganj.
# The closest hotel to Forsytheganj is гостиница Светочь.
# ------------
# Retrieving Results for Index 331: Clyde River.
# The closest hotel to Clyde River is Naujaaraaluit – Clyde River Hotel.
# ------------
# Retrieving Results for Index 332: Makakilo City.
# The closest hotel to Makakilo City is Hampton Inn & Suites Oahu/Kapolei.
# ------------
# Retrieving Results for Index 333: Nanticoke.
# ---Missing info... skipping---.
# ------------
# Retrieving Results for Index 334: Sabirabad.
# ---Missing info... skipping---.
# ------------
# Retrieving Results for Index 335: Mount Gambier.
# The closest hotel to Mount Gambier is The Commodore.
# ------------
# Retrieving Results for Index 336: Chokurdakh.
# ---Missing info... skipping---.
# ------------
# Retrieving Results for Index 337: Vila Franca do Campo.
# The closest hotel to Vila Franca do Campo is Pestana Bahia Praia.
# ------------
# Retrieving Results for Index 338: Nur-Sultan.
# The closest hotel to Nur-Sultan is Radisson Hotel, Astana.
# ------------
# Retrieving Results for Index 339: Nouadhibou.
# The closest hotel to Nouadhibou is Hotel Delphin-Nouadhibou.
# ------------
# Retrieving Results for Index 340: Ozernovskiy.
# ---Missing info... skipping---.
# ------------
# Retrieving Results for Index 341: Souillac.
# The closest hotel to Souillac is Shanti Maurice Resort & Spa.
# ------------
# Retrieving Results for Index 342: Kumul.
# The closest hotel to Kumul is 哈密环球大酒店.
# ------------
# Retrieving Results for Index 343: Rawson.
# The closest hotel to Rawson is Complejo Bahia Ballenas.
# ------------
# Retrieving Results for Index 344: Tommot.
# ---Missing info... skipping---.
# ------------
# Retrieving Results for Index 345: Opuwo.
# The closest hotel to Opuwo is Opuwo Country Lodge.
# ------------
# Retrieving Results for Index 346: Tuatapere.
# The closest hotel to Tuatapere is Tui Base Camp Motels.
# ------------
# Retrieving Results for Index 347: Kaliningrad.
# The closest hotel to Kaliningrad is Holiday Inn Kaliningrad, an IHG Hotel.
# ------------
# Retrieving Results for Index 348: Illapel.
# The closest hotel to Illapel is Hotel Diaguitas Illapel.
# ------------
# Retrieving Results for Index 349: Katima Mulilo.
# The closest hotel to Katima Mulilo is Protea Hotel by Marriott Zambezi River Lodge.
# ------------
# Retrieving Results for Index 350: Sur.
# The closest hotel to Sur is Sur Grand Hotel.
# ------------
# Retrieving Results for Index 351: Presidente Venceslau.
# The closest hotel to Presidente Venceslau is K. Hotel.
# ------------
# Retrieving Results for Index 352: Chengde.
# The closest hotel to Chengde is Chengde Qiwanglou Hotel.
# ------------
# Retrieving Results for Index 353: Tanabe.
# The closest hotel to Tanabe is Shirahama Nanki (formerly Asahi) Resort Hotel Shirahama.
# ------------
# Retrieving Results for Index 354: Bongandanga.
# ---Missing info... skipping---.
# ------------
# Retrieving Results for Index 355: Jerez.
# ---Missing info... skipping---.
# ------------
# Retrieving Results for Index 356: Jacareacanga.
# ---Missing info... skipping---.
# ------------
# Retrieving Results for Index 357: Kato Souli.
# The closest hotel to Kato Souli is Seaview Peninsula villa.
# ------------
# Retrieving Results for Index 358: İdil.
# ---Missing info... skipping---.
# ------------
# Retrieving Results for Index 359: Kongolo.
# ---Missing info... skipping---.
# ------------
# Retrieving Results for Index 360: Harper.
# ---Missing info... skipping---.
# ------------
# Retrieving Results for Index 361: Muzhi.
# ---Missing info... skipping---.
# ------------
# Retrieving Results for Index 362: Pangai.
# The closest hotel to Pangai is Ha'apai Beach Resort.
# ------------
# Retrieving Results for Index 363: Yerbogachën.
# ---Missing info... skipping---.
# ------------
# Retrieving Results for Index 364: Zambezi.
# ---Missing info... skipping---.
# ------------
# Retrieving Results for Index 365: Benjamin Constant.
# The closest hotel to Benjamin Constant is Hotel Benjamin Constant.
# ------------
# Retrieving Results for Index 366: Ust-Kuyga.
# ---Missing info... skipping---.
# ------------
# Retrieving Results for Index 367: Nicoya.
# The closest hotel to Nicoya is Hotel Cielo Azul.
# ------------
# Retrieving Results for Index 368: Lorengau.
# The closest hotel to Lorengau is Lorengau Harbourside Hotel.
# ------------
# Retrieving Results for Index 369: Mitsamiouli.
# ---Missing info... skipping---.
# ------------
# Retrieving Results for Index 370: Kungurtug.
# ---Missing info... skipping---.
# ------------
# Retrieving Results for Index 371: Chalon-sur-Saône.
# The closest hotel to Chalon-sur-Saône is Hôtel Saint Régis.
# ------------
# Retrieving Results for Index 372: Marawi.
# ---Missing info... skipping---.
# ------------
# Retrieving Results for Index 373: Beringovskiy.
# ---Missing info... skipping---.
# ------------
# Retrieving Results for Index 374: Vardø.
# The closest hotel to Vardø is Vardø Hotel AS.
# ------------
# Retrieving Results for Index 375: Aksu.
# The closest hotel to Aksu is Mingfu Business Hotel.
# ------------
# Retrieving Results for Index 376: Airai.
# ---Missing info... skipping---.
# ------------
# Retrieving Results for Index 377: Shuya.
# The closest hotel to Shuya is Grand Hotel Shuya.
# ------------
# Retrieving Results for Index 378: The Valley.
# The closest hotel to The Valley is Shoal Bay Villas.
# ------------
# Retrieving Results for Index 379: Moindou.
# ---Missing info... skipping---.
# ------------
# Retrieving Results for Index 380: Tazovsky.
# The closest hotel to Tazovsky is Hotel Tazovchanka.
# ------------
# Retrieving Results for Index 381: Lerwick.
# The closest hotel to Lerwick is The Grand Hotel.
# ------------
# Retrieving Results for Index 382: Leningradskiy.
# ---Missing info... skipping---.
# ------------
# Retrieving Results for Index 383: Stokmarknes.
# The closest hotel to Stokmarknes is Vesterålen Kysthotell.
# ------------
# Retrieving Results for Index 384: Jizan.
# ---Missing info... skipping---.
# ------------
# Retrieving Results for Index 385: Big Spring.
# The closest hotel to Big Spring is Hampton Inn & Suites Big Spring.
# ------------
# Retrieving Results for Index 386: Atambua.
# The closest hotel to Atambua is Hotel King Star.
# ------------
# Retrieving Results for Index 387: Shitanjing.
# ---Missing info... skipping---.
# ------------
# Retrieving Results for Index 388: Pengcheng.
# The closest hotel to Pengcheng is Wowo Boutique Hotel.
# ------------
# Retrieving Results for Index 389: Martin.
# ---Missing info... skipping---.
# ------------
# Retrieving Results for Index 390: Sukhumi.
# The closest hotel to Sukhumi is Гаруда бутик-отель.
# ------------
# Retrieving Results for Index 391: Sungai Penuh.
# The closest hotel to Sungai Penuh is PENGINAPAN DZAKY SUNGAI PENUH (Penginapan Syari'ah).
# ------------
# Retrieving Results for Index 392: Arroyo Grande.
# The closest hotel to Arroyo Grande is The Agrarian Hotel, BW Signature Collection.
# ------------
# Retrieving Results for Index 393: Verāval.
# The closest hotel to Verāval is Lords Inn Somnath.
# ------------
# Retrieving Results for Index 394: Conakry.
# The closest hotel to Conakry is Primus Hôtel Kaloum.
# ------------
# Retrieving Results for Index 395: Kānker.
# The closest hotel to Kānker is Hotel Anandam.
# ------------
# Retrieving Results for Index 396: Nome.
# The closest hotel to Nome is Aurora Inn & Suites.
# ------------
# Retrieving Results for Index 397: Norwich.
# ---Missing info... skipping---.
# ------------
# Retrieving Results for Index 398: Iqaluit.
# The closest hotel to Iqaluit is Aqsarniit Hotel & Conference Centre.
# ------------
# Retrieving Results for Index 399: Puerto Escondido.
# The closest hotel to Puerto Escondido is Villas Carrizalillo Hotel.
# ------------
# Retrieving Results for Index 400: Bilma.
# ---Missing info... skipping---.
# ------------
# Retrieving Results for Index 401: Hecun.
# The closest hotel to Hecun is Xiangtang Shanju Hotel.
# ------------
# Retrieving Results for Index 402: Eyl.
# ---Missing info... skipping---.
# ------------
# Retrieving Results for Index 403: Durango.
# ---Missing info... skipping---.
# ------------
# Retrieving Results for Index 404: Kalmunai.
# The closest hotel to Kalmunai is Villa LUXEZ.
# ------------
# Retrieving Results for Index 405: Nagato.
# The closest hotel to Nagato is Familylodge HATAGOYA Nagato.
# ------------
# Retrieving Results for Index 406: Conde.
# ---Missing info... skipping---.
# ------------
# Retrieving Results for Index 407: Lagos.
# ---Missing info... skipping---.
# ------------
# Retrieving Results for Index 408: Robertsport.
# The closest hotel to Robertsport is Kwepunha Retreat.
# ------------
# Retrieving Results for Index 409: Turochak.
# ---Missing info... skipping---.
# ------------
# Retrieving Results for Index 410: Gigmoto.
# The closest hotel to Gigmoto is Cj's Travellers Inn.
# ------------
# Retrieving Results for Index 411: Atasū.
# ---Missing info... skipping---.
# ------------
# Retrieving Results for Index 412: Esmeralda.
# ---Missing info... skipping---.
# ------------
# Retrieving Results for Index 413: Pitimbu.
# The closest hotel to Pitimbu is Pousada O Nativo.
# ------------
# Retrieving Results for Index 414: Tigzirt.
# The closest hotel to Tigzirt is Hôtel Mizrana Tigzirt.
# ------------
# Retrieving Results for Index 415: Saldanha.
# The closest hotel to Saldanha is Saldanha Bay Hotel.
# ------------
# Retrieving Results for Index 416: Tubli.
# ---Missing info... skipping---.
# ------------
# Retrieving Results for Index 417: Mastic Beach.
# The closest hotel to Mastic Beach is Smith Point Motel.
# ------------
# Retrieving Results for Index 418: Saint-Raphaël.
# The closest hotel to Saint-Raphaël is Adouly Hôtel.
# ------------
# Retrieving Results for Index 419: Aasiaat.
# The closest hotel to Aasiaat is Hotel Aasiaat Sømandshjem.
# ------------
# Retrieving Results for Index 420: Ilebo.
# ---Missing info... skipping---.
# ------------
# Retrieving Results for Index 421: Lamu.
# The closest hotel to Lamu is The Majlis Hotel Lamu.
# ------------
# Retrieving Results for Index 422: Inuvik.
# The closest hotel to Inuvik is Mackenzie Hotel.
# ------------
# Retrieving Results for Index 423: Stavern.
# The closest hotel to Stavern is Hotel Wassilioff.
# ------------
# Retrieving Results for Index 424: Oudtshoorn.
# The closest hotel to Oudtshoorn is Rosenhof Country House.
# ------------
# Retrieving Results for Index 425: Nabire.
# The closest hotel to Nabire is Hotel Grand Papua Nabire.
# ------------
# Retrieving Results for Index 426: Dongsheng.
# The closest hotel to Dongsheng is Crowne Plaza Ordos.
# ------------
# Retrieving Results for Index 427: Bonthe.
# ---Missing info... skipping---.
# ------------
# Retrieving Results for Index 428: Pacific Grove.
# The closest hotel to Pacific Grove is Hotel 1110.
# ------------
# Retrieving Results for Index 429: Aswān.
# The closest hotel to Aswān is Sofitel Legend Old Cataract Aswan.
# ------------
# Retrieving Results for Index 430: Periyapatti.
# ---Missing info... skipping---.
# ------------
# Retrieving Results for Index 431: Baghdad.
# The closest hotel to Baghdad is Al-Mansour Hotel.
# ------------
# Retrieving Results for Index 432: Pāli.
# The closest hotel to Pāli is HOTEL THE AMBA VILAS.
# ------------
# Retrieving Results for Index 433: Kolokani.
# ---Missing info... skipping---.
# ------------
# Retrieving Results for Index 434: Ilhabela.
# The closest hotel to Ilhabela is Itapemar Hotel.
# ------------
# Retrieving Results for Index 435: Walvis Bay.
# The closest hotel to Walvis Bay is Flamingo Villas Boutique Hotel.
# ------------
# Retrieving Results for Index 436: Collie.
# The closest hotel to Collie is Federal Hotel.
# ------------
# Retrieving Results for Index 437: Krasnoarmiys'k.
# The closest hotel to Krasnoarmiys'k is Hotelʹ "Melodiya".
# ------------
# Retrieving Results for Index 438: Blackwater.
# The closest hotel to Blackwater is The Capricorn Hotel Motor Inn.
# ------------
# Retrieving Results for Index 439: Polunochnoye.
# ---Missing info... skipping---.
# ------------
# Retrieving Results for Index 440: Cherskiy.
# ---Missing info... skipping---.
# ------------
# Retrieving Results for Index 441: Hobyo.
# ---Missing info... skipping---.
# ------------
# Retrieving Results for Index 442: Grindavik.
# The closest hotel to Grindavik is The Retreat at Blue Lagoon Iceland.
# ------------
# Retrieving Results for Index 443: Wilmington.
# The closest hotel to Wilmington is Hotel Ballast Wilmington, Tapestry Collection by Hilton.
# ------------
# Retrieving Results for Index 444: Uyo.
# The closest hotel to Uyo is Rosmohr Hotel & Suites.
# ------------
# Retrieving Results for Index 445: Jalu.
# ---Missing info... skipping---.
# ------------
# Retrieving Results for Index 446: Takhli.
# The closest hotel to Takhli is บ้านเพลิน.
# ------------
# Retrieving Results for Index 447: Ivaiporã.
# The closest hotel to Ivaiporã is Vilhar Palace Hotel.
# ------------
# Retrieving Results for Index 448: Lakes Entrance.
# The closest hotel to Lakes Entrance is The Esplanade Resort & Spa.
# ------------
# Retrieving Results for Index 449: Kamenka.
# ---Missing info... skipping---.
# ------------
# Retrieving Results for Index 450: Gijang.
# The closest hotel to Gijang is Ananti Hilton Busan.
# ------------
# Retrieving Results for Index 451: Melo.
# The closest hotel to Melo is Hotel Imperial.
# ------------
# Retrieving Results for Index 452: Vysokogornyy.
# ---Missing info... skipping---.
# ------------
# Retrieving Results for Index 453: La Ronge.
# The closest hotel to La Ronge is The Harbour Inn.
# ------------
# Retrieving Results for Index 454: Utamysh.
# ---Missing info... skipping---.
# ------------
# Retrieving Results for Index 455: Loreto.
# The closest hotel to Loreto is Holtel San Juaquin.
# ------------
# Retrieving Results for Index 456: Río Gallegos.
# The closest hotel to Río Gallegos is Amerian Hotel Apart And Suites.
# ------------
# Retrieving Results for Index 457: Guerrero Negro.
# The closest hotel to Guerrero Negro is The Halfway Inn.
# ------------
# Retrieving Results for Index 458: Najrān.
# ---Missing info... skipping---.
# ------------
# Retrieving Results for Index 459: Mayumba.
# ---Missing info... skipping---.
# ------------
# Retrieving Results for Index 460: Mwinilunga.
# ---Missing info... skipping---.
# ------------
# Retrieving Results for Index 461: Arrondissement d'Arcachon.
# The closest hotel to Arrondissement d'Arcachon is Hôtel All Suites Le Teich.
# ------------
# Retrieving Results for Index 462: Ayagoz.
# ---Missing info... skipping---.
# ------------
# Retrieving Results for Index 463: Borovoy.
# The closest hotel to Borovoy is Tsimus.
# ------------
# Retrieving Results for Index 464: Sevierville.
# The closest hotel to Sevierville is Hampton Inn Sevierville.
# ------------
# Retrieving Results for Index 465: Bairiki Village.
# The closest hotel to Bairiki Village is The George Hotel Kiribati.
# ------------
# Retrieving Results for Index 466: Yangi Marg`ilon.
# The closest hotel to Yangi Marg`ilon is TANTANA HOTEL FERGANA.
# ------------
# Retrieving Results for Index 467: Dinguiraye.
# ---Missing info... skipping---.
# ------------
# Retrieving Results for Index 468: Eureka.
# The closest hotel to Eureka is Best Western Plus Humboldt Bay Inn.
# ------------
# Retrieving Results for Index 469: Starachowice.
# The closest hotel to Starachowice is Hotel Europa.
# ------------
# Retrieving Results for Index 470: Srīvardhan.
# The closest hotel to Srīvardhan is Harihareshwar Beach Resort.
# ------------
# Retrieving Results for Index 471: Tynda.
# The closest hotel to Tynda is Na Presne.
# ------------
# Retrieving Results for Index 472: Sigli.
# The closest hotel to Sigli is Safira Hotel.
# ------------
# Retrieving Results for Index 473: Maragogi.
# The closest hotel to Maragogi is Pousada Sol & Mar - Maragogi.
# ------------
# Retrieving Results for Index 474: Cruzeiro.
# The closest hotel to Cruzeiro is Hotel Embaixador.
# ------------
# Retrieving Results for Index 475: Ribeira Brava.
# The closest hotel to Ribeira Brava is Enotel Sunset Bay.
# ------------
# Retrieving Results for Index 476: Zhirnovsk.
# The closest hotel to Zhirnovsk is Hotel "Forest Glade".
# ------------
# Retrieving Results for Index 477: Cervo.
# The closest hotel to Cervo is Palacio de Cristal.
# ------------
# Retrieving Results for Index 478: Lynn Haven.
# The closest hotel to Lynn Haven is Wingate by Wyndham Panama City Area Lynn Haven.
# ------------
# Retrieving Results for Index 479: Taoudenni.
# ---Missing info... skipping---.
# ------------
# Retrieving Results for Index 480: Vilyuysk.
# ---Missing info... skipping---.
# ------------
# Retrieving Results for Index 481: Karpogory.
# The closest hotel to Karpogory is Hotel Pinezhskaya Sloboda.
# ------------
# Retrieving Results for Index 482: Pisco.
# The closest hotel to Pisco is Hotel San Isidro Oficial.
# ------------
# Retrieving Results for Index 483: Uvira.
# ---Missing info... skipping---.
# ------------
# Retrieving Results for Index 484: Nishihara.
# The closest hotel to Nishihara is Glory island okinawa Yabusachi Resort.
# ------------
# Retrieving Results for Index 485: Manakara.
# The closest hotel to Manakara is Hotel H1 Manakara.
# ------------
# Retrieving Results for Index 486: Uray.
# The closest hotel to Uray is Hotel Pioner.
# ------------
# Retrieving Results for Index 487: Iquique.
# The closest hotel to Iquique is Hilton Garden Inn Iquique.
# ------------
# Retrieving Results for Index 488: Zlynka.
# ---Missing info... skipping---.
# ------------
# Retrieving Results for Index 489: Lagoa.
# The closest hotel to Lagoa is Graciosa Resort - Biosphere Island Hotel.
# ------------
# Retrieving Results for Index 490: Ladário.
# The closest hotel to Ladário is Pousada Pantanal.
# ------------
# Retrieving Results for Index 491: Abu Samrah.
# ---Missing info... skipping---.
# ------------
# Retrieving Results for Index 492: Novorzhev.
# ---Missing info... skipping---.
# ------------
# Retrieving Results for Index 493: Kununurra.
# The closest hotel to Kununurra is The Kimberley Grande Resort.
# ------------
# Retrieving Results for Index 494: Gunnedah.
# The closest hotel to Gunnedah is Gunnedah Hotel + VITA Restaurant.
# ------------
# Retrieving Results for Index 495: San Jose.
# The closest hotel to San Jose is Signia by Hilton San Jose.
# ------------
# Retrieving Results for Index 496: Van Wert.
# The closest hotel to Van Wert is Holiday Inn Express & Suites Van Wert, an IHG Hotel.
# ------------
# Retrieving Results for Index 497: Khor.
# The closest hotel to Khor is Provintsiya.
# ------------
# Retrieving Results for Index 498: Yar-Sale.
# The closest hotel to Yar-Sale is Yalemd.
# ------------
# Retrieving Results for Index 499: Biltine.
# ---Missing info... skipping---.
# ------------
# Retrieving Results for Index 500: Ola.
# ---Missing info... skipping---.
# ------------
# Retrieving Results for Index 501: Zhigansk.
# ---Missing info... skipping---.
# ------------
# Retrieving Results for Index 502: Parabel'.
# The closest hotel to Parabel' is Gostinitsa Berloga.
# ------------
# Retrieving Results for Index 503: Plaisir.
# The closest hotel to Plaisir is Le Clos Saint Nicolas.
# ------------
# Retrieving Results for Index 504: Boca do Acre.
# The closest hotel to Boca do Acre is Hotel Alice.
# ------------
# Retrieving Results for Index 505: Pangody.
# The closest hotel to Pangody is Хостел Адмиралъ.
# ------------
# Retrieving Results for Index 506: Kailua.
# The closest hotel to Kailua is Sheffield House Bed & Breakfast.
# ------------
# Retrieving Results for Index 507: Tianpeng.
# The closest hotel to Tianpeng is Ibis Hotel.
# ------------
# Retrieving Results for Index 508: Namatanai.
# ---Missing info... skipping---.
# ------------
# Retrieving Results for Index 509: San Juan.
# The closest hotel to San Juan is Hotel Alkazar.
# ------------
# Retrieving Results for Index 510: Kintinku.
# ---Missing info... skipping---.
# ------------
# Retrieving Results for Index 511: Kodinsk.
# ---Missing info... skipping---.
# ------------
# Retrieving Results for Index 512: Richards Bay.
# The closest hotel to Richards Bay is BON Hotel Waterfront Richards Bay.
# ------------
# Retrieving Results for Index 513: São João da Barra.
# The closest hotel to São João da Barra is Pousada Porto Prime.
# ------------
# Retrieving Results for Index 514: Marabu.
# The closest hotel to Marabu is Miri Marriott Resort & Spa.
# ------------
# Retrieving Results for Index 515: Caiapônia.
# The closest hotel to Caiapônia is Hotel Caetano.
# ------------
# Retrieving Results for Index 516: Kargasok.
# The closest hotel to Kargasok is Hotel Kargasok.
# ------------
# Retrieving Results for Index 517: Mamakan.
# ---Missing info... skipping---.
# ------------
# Retrieving Results for Index 518: Omsukchan.
# ---Missing info... skipping---.
# ------------
# Retrieving Results for Index 519: Vostok.
# ---Missing info... skipping---.
# ------------
# Retrieving Results for Index 520: Kiunga.
# ---Missing info... skipping---.
# ------------
# Retrieving Results for Index 521: Iralaya.
# ---Missing info... skipping---.
# ------------
# Retrieving Results for Index 522: Dawan.
# ---Missing info... skipping---.
# ------------
# Retrieving Results for Index 523: Shingū.
# The closest hotel to Shingū is Hotel New Palace.
# ------------
# Retrieving Results for Index 524: Sonqor.
# ---Missing info... skipping---.
# ------------
# Retrieving Results for Index 525: Churapcha.
# The closest hotel to Churapcha is "Tusku".
# ------------
# Retrieving Results for Index 526: Mamu Kanjan.
# ---Missing info... skipping---.
# ------------
# Retrieving Results for Index 527: Emerald.
# The closest hotel to Emerald is Emerald Star Hotel.
# ------------
# Retrieving Results for Index 528: Shache.
# The closest hotel to Shache is Chuangyuan Grand Hotel.
# ------------
# Retrieving Results for Index 529: Ogdensburg.
# The closest hotel to Ogdensburg is The Inn at Gran View.
# ------------
# Retrieving Results for Index 530: Oistins.
# The closest hotel to Oistins is Golden Sands Hotel.
# ------------
# Retrieving Results for Index 531: Chirongui.
# The closest hotel to Chirongui is Les Baobabs.
# ------------
# Retrieving Results for Index 532: Lázaro Cárdenas.
# The closest hotel to Lázaro Cárdenas is JP Hotel & Suites.
# ------------
# Retrieving Results for Index 533: Sambava.
# The closest hotel to Sambava is Melrose.
# ------------
# Retrieving Results for Index 534: Kŭlob.
# The closest hotel to Kŭlob is Gostinitsa "Sakho-Kulyab".
# ------------
# Retrieving Results for Index 535: Marsh Harbour.
# The closest hotel to Marsh Harbour is Abaco Beach Resort.
# ------------
# Retrieving Results for Index 536: Mogadishu.
# The closest hotel to Mogadishu is Dolphin Hotel.
# ------------
# Retrieving Results for Index 537: Lingao.
# The closest hotel to Lingao is Country Garden Golden Beach Spring Hotel.
# ------------
# Retrieving Results for Index 538: Laguna.
# The closest hotel to Laguna is Hampton Inn & Suites Sacramento-Elk Grove Laguna I-5.
# ------------
# Retrieving Results for Index 539: Lucapa.
# ---Missing info... skipping---.
# ------------
# Retrieving Results for Index 540: Adrar.
# ---Missing info... skipping---.
# ------------
# Retrieving Results for Index 541: Kuching.
# The closest hotel to Kuching is The Waterfront Hotel.
# ------------
# Retrieving Results for Index 542: Kontagora.
# The closest hotel to Kontagora is Hard Resource lodge.
# ------------
# Retrieving Results for Index 543: Düzce.
# The closest hotel to Düzce is Royal Business Hotel & Restaurant.
# ------------
# Retrieving Results for Index 544: Anadyr.
# The closest hotel to Anadyr is Chukotka hotel.
# ------------
# Retrieving Results for Index 545: Aksarka.
# ---Missing info... skipping---.
# ------------
# Retrieving Results for Index 546: Tungor.
# ---Missing info... skipping---.
# ------------
# Retrieving Results for Index 547: Mirny.
# The closest hotel to Mirny is Gostevoy Dom "Uyutnyy".
# ------------
# Retrieving Results for Index 548: Japura.
# ---Missing info... skipping---.
# ------------
# Retrieving Results for Index 549: Grand-Santi.
# ---Missing info... skipping---.
# ------------
# Retrieving Results for Index 550: Puerto Madryn.
# The closest hotel to Puerto Madryn is Hotel Península Valdés.
# ------------
# Retrieving Results for Index 551: Mossamedes.
# The closest hotel to Mossamedes is Hotel Chik Chik Namibe.
# ------------
# Retrieving Results for Index 552: Salinópolis.
# The closest hotel to Salinópolis is Hotel Privê do Atalaia.
# ------------
# Retrieving Results for Index 553: Belmonte.
# The closest hotel to Belmonte is Pousada do Diogo.
# ------------
# Retrieving Results for Index 554: Saskylakh.
# ---Missing info... skipping---.
# ------------
# Retrieving Results for Index 555: Broken Hill.
# The closest hotel to Broken Hill is Royal Exchange Hotel.
# ------------
# Retrieving Results for Index 556: Thayetmyo.
# ---Missing info... skipping---.
# ------------
# Retrieving Results for Index 557: Estelle.
# ---Missing info... skipping---.
# ------------
# Retrieving Results for Index 558: Sabang.
# The closest hotel to Sabang is Casa Nemo Beach Resort & Spa.
# ------------
# Retrieving Results for Index 559: Havelock.
# The closest hotel to Havelock is Hampton Inn Havelock.
# ------------
# Retrieving Results for Index 560: Geraldton.
# The closest hotel to Geraldton is Ocean Centre Hotel - Stay Beachside in Geraldton!.
# ------------
# Retrieving Results for Index 561: Leshukonskoye.
# The closest hotel to Leshukonskoye is Pryalitsa Hostel.
# ------------
# ------Search Complete-------

# %%
# NOTE: Do not change any of the code in this cell
# Analyze the code below for variables but these should be all columns in hotel_df

# Using the template add the hotel marks to the heatmap
info_box_template = """
<dl>
<dt>Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
</dl>
"""
# Store the DataFrame Row
# NOTE: be sure to update with your DataFrame name
hotel_info = [info_box_template.format(**row) for index, row in hotel_df.iterrows()]
locations = hotel_df[["Lat", "Lng"]]

# %%
# Add marker layer ontop of heat map
markers = gmaps.marker_layer(locations, info_box_content = hotel_info)

# Add the layer to the map
fig.add_layer(markers)

# Display Map
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
